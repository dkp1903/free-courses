# %%
from bs4 import BeautifulSoup
import requests

response = requests.get("https://www.udacity.com/courses/all")
html_soup = BeautifulSoup(response.content, 'html.parser')

#find all the URLs (items in the html where href exists)
url = html_soup.find_all(href=True)

#Iterate through the urls, and only return the ones that contain course and --
links = []
for u in url:
    if (u['href'].find('course') != -1):
        if (u['href'].find('--') != -1):
            if (u['href'].find('nanodegree') == -1 and u['href'].find('--nd') == -1):
                links.append(u['href'])
            
#remove duplicates by converting the list of links to a set, then back to a list
links = list(set(links)) 
links
# Out:
# ['/course/data-analysis-with-r--ud651',
#  '/course/machine-learning-for-trading--ud501',
#  '/course/gt-refresher-advanced-os--ud098',
#  '/course/intro-to-psychology--ps001',
#  '/course/auto-layout--ud1026',
#  '/course/how-to-install-android-studio--ud808',
#  '/course/intro-to-data-science--ud359',
#  '/course/objective-c-for-swift-developers--ud1009',
#  '/course/java-programming-basics--ud282',
#  '/course/intro-to-backend--ud171',
#  '/course/android-performance--ud825',
#  '/course/mobile-design-and-usability-for-android--ud358',
#  '/course/app-monetization--ud518',
#  '/course/classification-models--ud978',
#  '/course/networking-for-web-developers--ud256',
#  '/course/artificial-intelligence-for-robotics--cs373',
#  '/course/engagement-monetization-mobile-games--ud407',
#  '/course/build-native-mobile-apps-with-flutter--ud905',
#  '/course/computer-networking--ud436',
#  '/course/web-accessibility--ud891',
#  '/course/firebase-analytics-ios--ud353',
#  '/course/intel-edge-AI-fundamentals-with-openvino--ud132',
#  '/course/self-driving-car-fundamentals-featuring-apollo--ud0419',
#  '/course/intro-to-descriptive-statistics--ud827',
#  '/course/front-end-frameworks--ud894',
#  '/course/mobile-design-and-usability-for-ios--ud1034',
#  '/course/cyber-physical-systems-security--ud279',
#  '/course/2d-game-development-with-libgdx--ud405',
#  '/course/front-end-interview-prep--ud250',
#  '/course/rapid-prototyping--ud723',
#  '/course/intro-to-ios-app-development-with-swift--ud585',
#  '/course/kotlin-for-android-developers--ud888',
#  '/course/ux-design-for-mobile-developers--ud849',
#  '/course/intro-to-tensorflow-lite--ud190',
#  '/course/interactive-3d-graphics--cs291',
#  '/course/shell-workshop--ud206',
#  '/course/intro-to-relational-databases--ud197',
#  '/course/javascript-testing--ud549',
#  '/course/designing-restful-apis--ud388',
#  '/course/intro-to-statistics--st101',
#  '/course/eigenvectors-and-eigenvalues--ud104',
#  '/course/compilers-theory-and-practice--ud168',
#  '/course/computability-complexity-algorithms--ud061',
#  '/course/ios-persistence-and-core-data--ud325',
#  '/course/server-side-swift--ud1031',
#  '/course/full-stack-foundations--ud088',
#  '/course/linear-algebra-refresher-course--ud953',
#  '/course/javascript-design-patterns--ud989',
#  '/course/client-server-communication--ud897',
#  '/course/swift-for-developers--ud1025',
#  '/course/applied-cryptography--cs387',
#  '/course/intro-to-hadoop-and-mapreduce--ud617',
#  '/course/kotlin-bootcamp-for-programmers--ud9011',
#  '/course/android-basics-data-storage--ud845',
#  '/course/differential-equations-in-action--cs222',
#  '/course/learn-swift-programming-syntax--ud902',
#  '/course/android-interview-prep--ud241',
#  '/course/craft-your-cover-letter--ud244',
#  '/course/data-science-interview-prep--ud944',
#  '/course/firebase-in-a-weekend-by-google-ios--ud0351',
#  '/course/intro-to-information-security--ud459',
#  '/course/advanced-android-app-development--ud855',
#  '/course/data-visualization-and-d3js--ud507',
#  '/course/intro-to-ajax--ud110',
#  '/course/data-visualization-in-tableau--ud1006',
#  '/course/high-performance-computer-architecture--ud007',
#  '/course/software-architecture-design--ud821',
#  '/course/advanced-operating-systems--ud189',
#  '/course/localization-essentials--ud610',
#  '/course/introduction-to-python--ud1110',
#  '/course/html5-canvas--ud292',
#  '/course/ab-testing--ud979',
#  '/course/intro-to-artificial-intelligence--cs271',
#  '/course/how-to-make-an-ios-app--ud607',
#  '/course/strengthen-your-linkedin-network-and-brand--ud242',
#  '/course/learn-spark-at-udacity--ud2002',
#  '/course/software-debugging--cs259',
#  '/course/problem-solving-with-advanced-analytics--ud976',
#  '/course/intro-to-devops--ud611',
#  '/course/xcode-debugging--ud774',
#  '/course/intro-to-physics--ph100',
#  '/course/offline-web-applications--ud899',
#  '/course/deep-learning-pytorch--ud188',
#  '/course/intro-to-cloud-computing--ud080',
#  '/course/configuring-linux-web-servers--ud299',
#  '/course/machine-learning-unsupervised-learning--ud741',
#  '/course/firebase-in-a-weekend-by-google-android--ud0352',
#  '/course/advanced-android-with-kotlin--ud940',
#  '/course/intro-to-theoretical-computer-science--cs313',
#  '/course/statistics--st095',
#  '/course/ios-networking-with-swift--ud421',
#  '/course/firebase-analytics-android--ud354',
#  '/course/intro-to-data-analysis--ud170',
#  '/course/intro-to-jquery--ud245',
#  '/course/high-performance-computing--ud281',
#  '/course/gradle-for-android-and-java--ud867',
#  '/course/how-to-make-a-platformer-using-libgdx--ud406',
#  '/course/knowledge-based-ai-cognitive-systems--ud409',
#  '/course/creating-an-analytical-dataset--ud977',
#  '/course/object-oriented-javascript--ud711',
#  '/course/intro-to-progressive-web-apps--ud811',
#  '/course/data-wrangling-with-mongodb--ud032',
#  '/course/vr-interview-prep--ud251',
#  '/course/javascript-and-the-dom--ud117',
#  '/course/reinforcement-learning--ud600',
#  '/course/model-building-and-validation--ud919',
#  '/course/web-tooling-automation--ud892',
#  '/course/responsive-images--ud882',
#  '/course/android-basics-user-interface--ud834',
#  '/course/programming-languages--cs262',
#  '/course/scalable-microservices-with-kubernetes--ud615',
#  '/course/deploying-a-hadoop-cluster--ud1000',
#  '/course/c-for-programmers--ud210',
#  '/course/material-design-for-android-developers--ud862',
#  '/course/website-performance-optimization--ud884',
#  '/course/android-basics-networking--ud843',
#  '/course/passwordless-login-solutions-for-ios--ud1028',
#  '/course/http-web-servers--ud303',
#  '/course/asynchronous-javascript-requests--ud109',
#  '/course/developing-android-apps-with-kotlin--ud9012',
#  '/course/database-systems-concepts-design--ud150',
#  '/course/real-time-analytics-with-apache-storm--ud381',
#  '/course/grand-central-dispatch-gcd--ud576',
#  '/course/javascript-promises--ud898',
#  '/course/time-series-forecasting--ud980',
#  '/course/the-mvc-pattern-in-ruby--ud270',
#  '/course/intro-to-point-click-app-development--ud162',
#  '/course/ab-testing--ud257',
#  '/course/linux-command-line-basics--ud595',
#  '/course/intro-to-javascript--ud803',
#  '/course/google-maps-apis--ud864',
#  '/course/cyber-physical-systems-design-analysis--ud9876',
#  '/course/embedded-systems--ud169',
#  '/course/app-marketing--ud719',
#  '/course/secure-and-private-ai--ud185',
#  '/course/software-testing--cs258',
#  '/course/version-control-with-git--ud123',
#  '/course/building-high-conversion-web-forms--ud890',
#  '/course/introduction-to-virtual-reality--ud1012',
#  '/course/what-is-programming--ud994',
#  '/course/managing-remote-teams-with-upwork--ud942',
#  '/course/data-analysis-and-visualization--ud404',
#  '/course/data-structures-and-algorithms-in-swift--ud1011',
#  '/course/introduction-to-graduate-algorithms--ud401',
#  '/course/how-to-build-a-startup--ep245',
#  '/course/android-basics-user-input--ud836',
#  '/course/intro-to-html-and-css--ud001',
#  '/course/uikit-fundamentals--ud788',
#  '/course/human-computer-interaction--ud400',
#  '/course/core-ml--ud1038',
#  '/course/aws-deepracer--ud014',
#  '/course/design-of-computer-programs--cs212',
#  '/course/network-security--ud199',
#  '/course/machine-learning--ud262',
#  '/course/machine-learning-interview-prep--ud1001',
#  '/course/passwordless-login-solutions-for-android--ud357',
#  '/course/intro-to-algorithms--cs215',
#  '/course/sql-for-data-analysis--ud198',
#  '/course/product-design--ud509',
#  '/course/ios-interview-prep--ud240',
#  '/course/artificial-intelligence--ud954',
#  '/course/product-manager-interview-preparation--ud034',
#  '/course/responsive-web-design-fundamentals--ud893',
#  '/course/full-stack-interview-prep--ud252',
#  '/course/intro-to-inferential-statistics--ud201',
#  '/course/object-oriented-programming-in-java--ud283',
#  '/course/dynamic-web-applications-with-sinatra--ud268',
#  '/course/deploying-applications-with-heroku--ud272',
#  '/course/introduction-to-computer-vision--ud810',
#  '/course/software-analysis-testing--ud333',
#  '/course/browser-rendering-optimization--ud860',
#  '/course/android-basics-multiscreen-apps--ud839',
#  '/course/es6-javascript-improved--ud356',
#  '/course/intro-to-tensorflow-for-deep-learning--ud187',
#  '/course/get-your-startup-started--ud806',
#  '/course/segmentation-and-clustering--ud981',
#  '/course/swift-for-beginners--ud1022',
#  '/course/big-data-analytics-in-healthcare--ud758',
#  '/course/wechat-mini-programs--ud667',
#  '/course/refresh-your-resume--ud243',
#  '/course/introduction-to-operating-systems--ud923',
#  '/course/software-development-process--ud805',
#  '/course/writing-readmes--ud777',
#  '/course/authentication-authorization-oauth--ud330',
#  '/course/new-android-fundamentals--ud851',
#  '/course/intro-to-machine-learning--ud120']

# %%
len(links)
# Out:
# 186

# %% [markdown]
# 186 courses :
#
# Each course URL will be visited in the following code to extract the information needed. The relevent HTML tags and class names were extracted by visiting the URL, right clicking on the element of interest and selecting Inspect to view the related HTML. This could then be used with the BeautifulSoup find and find_all functions to get the information.

# %%
import time
from random import randint

#initilise the lists to store the extracted info
course_names = []
course_urls = []
course_nanodegrees = []
course_costs = []

# Preparing the monitoring of the loop
start_time = time.time()
requests_count = 0

#iterate through each link to extract info about the nano degree it belongs to and the cost
for i in range(len(links)):
    #need to make requests at random times in order to not be blocked by website
    time.sleep(randint(2,6)) 
    url = "https://www.udacity.com" + links[i]
    response = requests.get(url)
    content = response.content
    html_soup = BeautifulSoup(content, 'html.parser')
    
    # Monitor the requests
    requests_count += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests_count, requests_count/elapsed_time))
    #clear_output(wait = True)
    
    # Break the loop if the number of requests is greater than expected
    if requests_count > 250:
        warn('Number of requests was greater than expected.')  
        break 
    
    try:
        nanodegree = html_soup.find('h3',class_="h1 hero__nanodegree--title").text
    except:
        nanodegree = 'None'
    try:
        course_name = html_soup.find('h1',class_='hero__course--title').text
    except:
        course_name = 'None'
    try:
        cost = html_soup.find('h6',class_='hero__course--type').text
    except:
        cost = 'None'
    course_names.append(course_name)
    course_urls.append(url)
    course_nanodegrees.append(nanodegree)
    course_costs.append(cost)
# Out:
# Request:1; Frequency: 0.30723007044317396 requests/s
# Request:2; Frequency: 0.26649758787603917 requests/s
# Request:3; Frequency: 0.2778304090832433 requests/s
# Request:4; Frequency: 0.28441414771033285 requests/s
# Request:5; Frequency: 0.30612204383735303 requests/s
# Request:6; Frequency: 0.3210213893891675 requests/s
# Request:7; Frequency: 0.2804222609796274 requests/s
# Request:8; Frequency: 0.27365660956369336 requests/s
# Request:9; Frequency: 0.2762723613554465 requests/s
# Request:10; Frequency: 0.2711005960775285 requests/s
# Request:11; Frequency: 0.2532987472980598 requests/s
# Request:12; Frequency: 0.24616476916264565 requests/s
# Request:13; Frequency: 0.25470122846014953 requests/s
# Request:14; Frequency: 0.2526767058029134 requests/s
# Request:15; Frequency: 0.2421179306250676 requests/s
# Request:16; Frequency: 0.24123349609279235 requests/s
# Request:17; Frequency: 0.2340058565223791 requests/s
# Request:18; Frequency: 0.2298633545083746 requests/s
# Request:19; Frequency: 0.23188989315948383 requests/s
# Request:20; Frequency: 0.23195185552749528 requests/s
# Request:21; Frequency: 0.22948921288547236 requests/s
# Request:22; Frequency: 0.2346561141355737 requests/s
# Request:23; Frequency: 0.23955328306474388 requests/s
# Request:24; Frequency: 0.2370329072587736 requests/s
# Request:25; Frequency: 0.2415562240197438 requests/s
# Request:26; Frequency: 0.2450492483875294 requests/s
# Request:27; Frequency: 0.24248402607347494 requests/s
# Request:28; Frequency: 0.2460992588836112 requests/s
# Request:29; Frequency: 0.24933376629556006 requests/s
# Request:30; Frequency: 0.25306975528727665 requests/s
# Request:31; Frequency: 0.2537467094956362 requests/s
# Request:32; Frequency: 0.2551941734643671 requests/s
# Request:33; Frequency: 0.2525936590753851 requests/s
# Request:34; Frequency: 0.2520071958464839 requests/s
# Request:35; Frequency: 0.25329263329556867 requests/s
# Request:36; Frequency: 0.2545851979590708 requests/s
# Request:37; Frequency: 0.25576168405344196 requests/s
# Request:38; Frequency: 0.253319993424889 requests/s
# Request:39; Frequency: 0.25450984782036257 requests/s
# Request:40; Frequency: 0.2519613005640863 requests/s
# Request:41; Frequency: 0.24996610227447275 requests/s
# Request:42; Frequency: 0.2455126997294281 requests/s
# Request:43; Frequency: 0.24249120120513407 requests/s
# Request:44; Frequency: 0.24500953063080744 requests/s
# Request:45; Frequency: 0.24476726445122254 requests/s
# Request:46; Frequency: 0.2432353149235096 requests/s
# Request:47; Frequency: 0.24062103347000338 requests/s
# Request:48; Frequency: 0.2381371025690115 requests/s
# Request:49; Frequency: 0.23916753266767313 requests/s
# Request:50; Frequency: 0.23912071235558363 requests/s
# Request:51; Frequency: 0.2368357020501421 requests/s
# Request:52; Frequency: 0.23764762241486015 requests/s
# Request:53; Frequency: 0.23756086318527245 requests/s
# Request:54; Frequency: 0.2353294897002039 requests/s
# Request:55; Frequency: 0.23435035328810452 requests/s
# Request:56; Frequency: 0.23435264970374614 requests/s
# Request:57; Frequency: 0.23534409192382028 requests/s
# Request:58; Frequency: 0.233434637613417 requests/s
# Request:59; Frequency: 0.2325320346356078 requests/s
# Request:60; Frequency: 0.23340396104724973 requests/s
# Request:61; Frequency: 0.2343340341831147 requests/s
# Request:62; Frequency: 0.23593800455410596 requests/s
# Request:63; Frequency: 0.2377013695545846 requests/s
# Request:64; Frequency: 0.2359002312735803 requests/s
# Request:65; Frequency: 0.23677062405480667 requests/s
# Request:66; Frequency: 0.2384018547994851 requests/s
# Request:67; Frequency: 0.23665509580013833 requests/s
# Request:68; Frequency: 0.23488905598981857 requests/s
# Request:69; Frequency: 0.23492168803174884 requests/s
# Request:70; Frequency: 0.23433996526538145 requests/s
# Request:71; Frequency: 0.23346236467450873 requests/s
# Request:72; Frequency: 0.2334723590530522 requests/s
# Request:73; Frequency: 0.23343114638916784 requests/s
# Request:74; Frequency: 0.23419563702415333 requests/s
# Request:75; Frequency: 0.23491585258671796 requests/s
# Request:76; Frequency: 0.23566013548397785 requests/s
# Request:77; Frequency: 0.23638493331192245 requests/s
# Request:78; Frequency: 0.2349475990649345 requests/s
# Request:79; Frequency: 0.23355098500822732 requests/s
# Request:80; Frequency: 0.23491137786227023 requests/s
# Request:81; Frequency: 0.2355628633019271 requests/s
# Request:82; Frequency: 0.23624678320249268 requests/s
# Request:83; Frequency: 0.23690971995167473 requests/s
# Request:84; Frequency: 0.23823816005002835 requests/s
# Request:85; Frequency: 0.23822646636101477 requests/s
# Request:86; Frequency: 0.23884372598246228 requests/s
# Request:87; Frequency: 0.23746490714599516 requests/s
# Request:88; Frequency: 0.23865475182938442 requests/s
# Request:89; Frequency: 0.237924163120845 requests/s
# Request:90; Frequency: 0.2366427237353868 requests/s
# Request:91; Frequency: 0.23723954627808883 requests/s
# Request:92; Frequency: 0.23779164664810604 requests/s
# Request:93; Frequency: 0.23829960827364274 requests/s
# Request:94; Frequency: 0.23685326733241466 requests/s
# Request:95; Frequency: 0.23673506758083313 requests/s
# Request:96; Frequency: 0.23590511687311166 requests/s
# Request:97; Frequency: 0.23531233429457304 requests/s
# Request:98; Frequency: 0.23449396624936053 requests/s
# Request:99; Frequency: 0.23506180723419703 requests/s
# Request:100; Frequency: 0.23506931275179296 requests/s
# Request:101; Frequency: 0.23400169713035965 requests/s
# Request:102; Frequency: 0.23510848504219967 requests/s
# Request:103; Frequency: 0.23403425650397103 requests/s
# Request:104; Frequency: 0.23299519830545176 requests/s
# Request:105; Frequency: 0.2324925040142752 requests/s
# Request:106; Frequency: 0.2318401990259156 requests/s
# Request:107; Frequency: 0.2327212724571693 requests/s
# Request:108; Frequency: 0.23225384492631054 requests/s
# Request:109; Frequency: 0.23321495031085118 requests/s
# Request:110; Frequency: 0.23373483968286546 requests/s
# Request:111; Frequency: 0.23276870688597767 requests/s
# Request:112; Frequency: 0.23183074951310118 requests/s
# Request:113; Frequency: 0.23284903346983157 requests/s
# Request:114; Frequency: 0.23336840380011345 requests/s
# Request:115; Frequency: 0.23387615337889608 requests/s
# Request:116; Frequency: 0.23342904755976557 requests/s
# Request:117; Frequency: 0.23390740692974385 requests/s
# Request:118; Frequency: 0.23429640483087813 requests/s
# Request:119; Frequency: 0.23476451871040926 requests/s
# Request:120; Frequency: 0.23522686290792355 requests/s
# Request:121; Frequency: 0.2360063742632548 requests/s
# Request:122; Frequency: 0.23543461617205408 requests/s
# Request:123; Frequency: 0.23633400920847256 requests/s
# Request:124; Frequency: 0.23721692259008936 requests/s
# Request:125; Frequency: 0.23628407394663073 requests/s
# Request:126; Frequency: 0.2353854778853457 requests/s
# Request:127; Frequency: 0.23564331537061256 requests/s
# Request:128; Frequency: 0.2352123876541398 requests/s
# Request:129; Frequency: 0.23479552230413303 requests/s
# Request:130; Frequency: 0.23549861373791317 requests/s
# Request:131; Frequency: 0.2346417054805275 requests/s
# Request:132; Frequency: 0.23464280094809117 requests/s
# Request:133; Frequency: 0.23504940755645132 requests/s
# Request:134; Frequency: 0.23588462660456108 requests/s
# Request:135; Frequency: 0.23671731295825882 requests/s
# Request:136; Frequency: 0.23701325634775675 requests/s
# Request:137; Frequency: 0.23657707717165247 requests/s
# Request:138; Frequency: 0.23738716324602444 requests/s
# Request:139; Frequency: 0.23696476872261654 requests/s
# Request:140; Frequency: 0.2376521223695959 requests/s
# Request:141; Frequency: 0.23799077981726768 requests/s
# Request:142; Frequency: 0.23874929122307523 requests/s
# Request:143; Frequency: 0.23908556728415153 requests/s
# Request:144; Frequency: 0.23865985560316283 requests/s
# Request:145; Frequency: 0.23902325048455875 requests/s
# Request:146; Frequency: 0.2381929624496363 requests/s
# Request:147; Frequency: 0.23847962577136989 requests/s
# Request:148; Frequency: 0.23802939726612649 requests/s
# Request:149; Frequency: 0.23840196537203737 requests/s
# Request:150; Frequency: 0.2387598483187069 requests/s
# Request:151; Frequency: 0.23912437881261012 requests/s
# Request:152; Frequency: 0.2390221258576713 requests/s
# Request:153; Frequency: 0.23976700892042796 requests/s
# Request:154; Frequency: 0.2393548336573553 requests/s
# Request:155; Frequency: 0.23967475992473092 requests/s
# Request:156; Frequency: 0.24034913380591866 requests/s
# Request:157; Frequency: 0.24087489501558107 requests/s
# Request:158; Frequency: 0.23985238977217413 requests/s
# Request:159; Frequency: 0.23939129842026322 requests/s
# Request:160; Frequency: 0.23936270341639482 requests/s
# Request:161; Frequency: 0.23969257157982815 requests/s
# Request:162; Frequency: 0.23931559534016753 requests/s
# Request:163; Frequency: 0.23927425907325242 requests/s
# Request:164; Frequency: 0.239856089273251 requests/s
# Request:165; Frequency: 0.23947649579500016 requests/s
# Request:166; Frequency: 0.23876258619001475 requests/s
# Request:167; Frequency: 0.2394150268995706 requests/s
# Request:168; Frequency: 0.23938064084038024 requests/s
# Request:169; Frequency: 0.23866939414452049 requests/s
# Request:170; Frequency: 0.23794904172644046 requests/s
# Request:171; Frequency: 0.23726458110687446 requests/s
# Request:172; Frequency: 0.23656851795224168 requests/s
# Request:173; Frequency: 0.23719816520592088 requests/s
# Request:174; Frequency: 0.23704487259990067 requests/s
# Request:175; Frequency: 0.23700796808984093 requests/s
# Request:176; Frequency: 0.23700789034041012 requests/s
# Request:177; Frequency: 0.2373326176141458 requests/s
# Request:178; Frequency: 0.2370078934337782 requests/s
# Request:179; Frequency: 0.23696391945167994 requests/s
# Request:180; Frequency: 0.23716351209733208 requests/s
# Request:181; Frequency: 0.2371593570564421 requests/s
# Request:182; Frequency: 0.23776466109786212 requests/s
# Request:183; Frequency: 0.23712763538463127 requests/s
# Request:184; Frequency: 0.23671836998821982 requests/s
# Request:185; Frequency: 0.2359974792214428 requests/s
# Request:186; Frequency: 0.23655894525727597 requests/s

# %%
#Convert the lists to a dataframe
import pandas as pd
courses_df = pd.DataFrame({'Name': course_names,
                          'URL': course_urls,
                          'Nanodegree': course_nanodegrees,
                          'Cost':course_costs})
courses_df = courses_df.sort_values('Nanodegree')
print(courses_df.info())
courses_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 171 to 143
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        186 non-null    object
#  1   URL         186 non-null    object
#  2   Nanodegree  186 non-null    object
#  3   Cost        186 non-null    object
# dtypes: object(4)
# memory usage: 7.3+ KB
# None
#                                          Name  ...         Cost
# 171          Android Basics: Multiscreen Apps  ...  Free Course
# 145                Android Basics: User Input  ...  Free Course
# 115                Android Basics: Networking  ...  Free Course
# 53               Android Basics: Data Storage  ...  Free Course
# 119       Developing Android Apps with Kotlin  ...  Free Course
# ..                                        ...  ...          ...
# 136                  Version Control with Git  ...  Free Course
# 3                         Intro to Psychology  ...  Free Course
# 131  Cyber-Physical Systems Design & Analysis  ...  Free Course
# 49                       Swift for Developers  ...  Free Course
# 143       Introduction to Graduate Algorithms  ...  Free Course
#
# [186 rows x 4 columns]

# %%
#Save to csv file
courses_df.to_csv('Udacity_Courses.csv')

# %% [markdown]
# To see which courses belonged to the Data Analyst degree, the courses data frame was filtered and a new data frame was created

# %%
data_analyst = courses_df[courses_df['Nanodegree'] == 'Data Analyst']
data_analyst
# Out:
#                                 Name  ...         Cost
# 148       Human-Computer Interaction  ...  Free Course
# 141  Data Analysis and Visualization  ...  Free Course
# 169      Software Analysis & Testing  ...  Free Course
# 23   Intro to Descriptive Statistics  ...  Free Course
#
# [4 rows x 4 columns]

# %%
from google.colab import files
files.download('Udacity_Courses.csv')
